# %% [markdown]
# <a href="https://colab.research.google.com/github/ivywanjage/cdav/blob/main/bmi%2Cshopping_list%2Cstudent_profile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(5!=5)
# Out:
# False

# %%
name=input("what is your name?")
age=input("what is your age?")
current_course=input("what is your current course?")
print("=================")
print("STUDENT PROFILE")
print("=================")
print("Name:",name)
print("Age:",age)
print("Current course:",current_course)
# Out:
# what is your name?ivy
# what is your age?19
# what is your current course?artistry
# ...
# STUDENT PROFILE
# ...
# Name: ivy
# Age: 19
# Current course: artistry

# %%
weight=int(input("what is your weight in kilograms?"))
height=float(input("what is your height in metres?"))
bmi=float(weight)/float(height**2)
print("your body mass index is",bmi)
# Out:
# what is your weight in kilograms?80
# what is your height in metres?1.6
# your body mass index is 31.249999999999993

# %%
item_name=(str(input("what is the name of the item? ")))
price=float(input("what is the price of the item? "))
quantity=int(input("what is the quantity of the item? "))
total=price*quantity
print("item name:",item_name)
print("price",price)
print("quantity",quantity)
print("total",total)
# Out:
# what is the name of the item? bread
# what is the price of the item? 120
# what is the quantity of the item? 2
# item name: bread
# price 120.0
# quantity 2
# total 240.0
