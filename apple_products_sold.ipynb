# %% [markdown]
# <a href="https://colab.research.google.com/github/ivywanjage/cdav/blob/main/apple_products_sold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas

# %%
# !pip install pandas

# %%
import pandas as pd
pd.__version__
pd.set_option("display.max_columns",None)

# %%
counties=pd.Series([4397073,1208333,2162202,1157073])
print(counties)

# %%
df=pd.read_csv("/content/apple_products_pricing_2020_2026.csv")
df.head()
# Out:
#          Date  Platform Product_Category                   Model_Name  \
# 0  2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1  2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2  2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3  2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4  2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
#
#   Condition  Launch_Price_USD  Launch_Price_INR  Current_Price_USD  \
# 0       New               429             42042             435.81
# 1       New               429             42042             436.49
# 2       New               429             42042             422.73
# 3       New               429             42042             425.00
# 4       New               429             42042             436.22
#
#    Current_Price_INR  Discount_Pct Sale_Event  Stock_Status  Rating  \
# 0           43322.41          -1.6        NaN      In Stock     4.7
# ...

# %%
df.tail()
# Out:
#              Date  Platform Product_Category       Model_Name  \
# 79995  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone  iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# 79995                  New               849             83202
# 79996                  New               849             83202
# 79997  Renewed/Refurbished               849             83202
# 79998  Renewed/Refurbished               849             83202
# 79999                  New               849             83202
#
#        Current_Price_USD  Current_Price_INR  Discount_Pct Sale_Event  \
# 79995             861.39           82894.76          -1.5        NaN
# 79996             832.50           81159.39           1.9        NaN
# ...

# %%
df.head(10)
# Out:
#          Date  Platform Product_Category                   Model_Name  \
# 0  2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1  2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2  2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3  2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4  2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# 5  2020-09-26  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 6  2020-09-27  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 7  2020-09-29  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 8  2020-10-01  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 9  2020-10-01    Amazon            Watch  Apple Watch Series 6 (44mm)
#
#              Condition  Launch_Price_USD  Launch_Price_INR  Current_Price_USD  \
# 0                  New               429             42042             435.81
# ...

# %%
df.tail(20)
# Out:
#              Date  Platform Product_Category               Model_Name  \
# 79980  2026-07-31    Amazon           iPhone          iPhone 14 128GB
# 79981  2026-07-31  Flipkart           iPhone          iPhone 15 128GB
# 79982  2026-07-31  Flipkart           iPhone          iPhone 15 128GB
# 79983  2026-07-31    Amazon           iPhone          iPhone 15 128GB
# 79984  2026-07-31  Flipkart           iPhone  iPhone 15 Pro Max 256GB
# 79985  2026-07-31  Flipkart           iPhone          iPhone 16 128GB
# 79986  2026-07-31  Flipkart           iPhone          iPhone 16 128GB
# 79987  2026-07-31    Amazon           iPhone          iPhone 16 128GB
# 79988  2026-07-31    Amazon           iPhone          iPhone 16 128GB
# 79989  2026-07-31    Amazon           iPhone          iPhone 17 128GB
# 79990  2026-07-31    Amazon           iPhone          iPhone 17 128GB
# 79991  2026-07-31  Flipkart           iPhone          iPhone 17 128GB
# ...

# %%
df.shape
# Out:
# (80000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               80000 non-null  object
#  1   Platform           80000 non-null  object
#  2   Product_Category   80000 non-null  object
#  3   Model_Name         80000 non-null  object
#  4   Condition          80000 non-null  object
#  5   Launch_Price_USD   80000 non-null  int64
#  6   Launch_Price_INR   80000 non-null  int64
#  7   Current_Price_USD  80000 non-null  float64
#  8   Current_Price_INR  80000 non-null  float64
#  9   Discount_Pct       80000 non-null  float64
#  10  Sale_Event         6649 non-null   object
#  11  Stock_Status       80000 non-null  object
#  12  Rating             80000 non-null  float64
#  13  Reviews_Count      80000 non-null  int64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 8.5+ MB

# %%
df.describe()
# Out:
#        Launch_Price_USD  Launch_Price_INR  Current_Price_USD  \
# count      80000.000000      80000.000000       80000.000000
# mean         963.959125      94467.994250         782.769855
# std          470.086413      46068.468464         461.673970
# min          329.000000      32242.000000         109.930000
# 25%          599.000000      58702.000000         432.930000
# 50%          799.000000      78302.000000         699.740000
# 75%         1199.000000     117502.000000         989.112500
# max         1999.000000     195902.000000        2038.970000
#
#        Current_Price_INR  Discount_Pct        Rating  Reviews_Count
# count       80000.000000  80000.000000  80000.000000   80000.000000
# mean        74628.342439     21.418826      4.450099    2405.995925
# std         45117.872172     16.697310      0.269782    1973.630852
# min          9157.680000     -2.000000      3.800000      10.000000
# 25%         41686.835000      6.700000      4.300000     896.000000
# ...

# %%
df.columns
#column names
# Out:
# Index(['Date', 'Platform', 'Product_Category', 'Model_Name', 'Condition',
#        'Launch_Price_USD', 'Launch_Price_INR', 'Current_Price_USD',
#        'Current_Price_INR', 'Discount_Pct', 'Sale_Event', 'Stock_Status',
#        'Rating', 'Reviews_Count'],
#       dtype='object')

# %%
df.dtypes
#the type of each column
# Out:
# Date                  object
# Platform              object
# Product_Category      object
# Model_Name            object
# Condition             object
# Launch_Price_USD       int64
# Launch_Price_INR       int64
# Current_Price_USD    float64
# Current_Price_INR    float64
# Discount_Pct         float64
# Sale_Event            object
# Stock_Status          object
# Rating               float64
# Reviews_Count          int64
# dtype: object

# %%
df.index
#the row labels
# Out:
# RangeIndex(start=0, stop=80000, step=1)

# %%
df.size
#the total number of cells
# Out:
# 1120000

# %%
df["Product_Category"].unique()
#what values appear in that specific column
# Out:
# array(['Watch', 'iPad', 'iPhone', 'Mac'], dtype=object)

# %%
df[["Model_Name","Product_Category"]]
# Out:
#                         Model_Name Product_Category
# 0      Apple Watch Series 6 (44mm)            Watch
# 1      Apple Watch Series 6 (44mm)            Watch
# 2      Apple Watch Series 6 (44mm)            Watch
# 3      Apple Watch Series 6 (44mm)            Watch
# 4      Apple Watch Series 6 (44mm)            Watch
# ...                            ...              ...
# 79995              iPhone 17 128GB           iPhone
# 79996              iPhone 17 128GB           iPhone
# 79997              iPhone 17 128GB           iPhone
# 79998              iPhone 17 128GB           iPhone
# 79999              iPhone 17 128GB           iPhone
#
# [80000 rows x 2 columns]

# %%
df.loc[2,"Platform"]
#row named 2,column named platform
# Out:
# 'Amazon'

# %%
df.iloc[2,2]
#second row,second column
# Out:
# 'Watch'

# %%
df["Product_Category"]=="Watch"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 79995    False
# 79996    False
# 79997    False
# 79998    False
# 79999    False
# Name: Product_Category, Length: 80000, dtype: bool

# %%
df["Reviews_Count"]>1000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 79995     True
# 79996    False
# 79997     True
# 79998    False
# 79999     True
# Name: Reviews_Count, Length: 80000, dtype: bool

# %%
df["Product_Category"]!="Watch"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 79995     True
# 79996     True
# 79997     True
# 79998     True
# 79999     True
# Name: Product_Category, Length: 80000, dtype: bool

# %%
s=pd.Series([10,25,30,45])
s>20
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# dtype: bool

# %%
df[df["Reviews_Count"]>1000]
# Out:
#              Date  Platform Product_Category                   Model_Name  \
# 1042   2021-03-28    Amazon            Watch  Apple Watch Series 6 (44mm)
# 1054   2021-03-30    Amazon            Watch  Apple Watch Series 6 (44mm)
# 1065   2021-04-01  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1074   2021-04-03    Amazon            Watch  Apple Watch Series 6 (44mm)
# 1075   2021-04-03  Flipkart            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79993  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79994  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79995  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
is_amazon=df["Platform"]=="Amazon"
is_large=df["Reviews_Count"]>1000
df[is_amazon&is_large]
# Out:
#              Date Platform Product_Category                   Model_Name  \
# 1042   2021-03-28   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1054   2021-03-30   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1074   2021-04-03   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1130   2021-04-10   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1145   2021-04-12   Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...      ...              ...                          ...
# 79988  2026-07-31   Amazon           iPhone              iPhone 16 128GB
# 79989  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79993  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79994  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79997  2026-07-31   Amazon           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
len(is_amazon)
is_amazon.shape
# Out:
# (80000,)

# %%
df[(df["Platform"]=="Amazon") &(df["Reviews_Count"]>1000)]
# Out:
#              Date Platform Product_Category                   Model_Name  \
# 1042   2021-03-28   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1054   2021-03-30   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1074   2021-04-03   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1130   2021-04-10   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1145   2021-04-12   Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...      ...              ...                          ...
# 79988  2026-07-31   Amazon           iPhone              iPhone 16 128GB
# 79989  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79993  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79994  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79997  2026-07-31   Amazon           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
#NOT amazon-the squiggle means 'not'
df[-(df["Platform"]=="Amazon")]
# Out:
#              Date  Platform Product_Category                   Model_Name  \
# 0      2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1      2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4      2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79995  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
#one of several,without a long chain of ORs
df[df["Product_Category"].isin(["iPhone","Watch","iPad"])]
# Out:
#              Date  Platform Product_Category                   Model_Name  \
# 0      2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1      2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4      2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79995  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
#between-inclusive at both ends
df[df["Reviews_Count"].between(500,1000)]
# Out:
#              Date  Platform Product_Category                   Model_Name  \
# 348    2020-12-16  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 349    2020-12-16  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 362    2020-12-18    Amazon            Watch  Apple Watch Series 6 (44mm)
# 370    2020-12-19    Amazon            Watch  Apple Watch Series 6 (44mm)
# 445    2020-12-29  Flipkart            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79929  2026-07-30    Amazon           iPhone              iPhone 17 128GB
# 79990  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79991  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
#query-the same filter,written as a sentence
df.query("Platform=='Amazon' and Reviews_Count>1000")
# Out:
#              Date Platform Product_Category                   Model_Name  \
# 1042   2021-03-28   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1054   2021-03-30   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1074   2021-04-03   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1130   2021-04-10   Amazon            Watch  Apple Watch Series 6 (44mm)
# 1145   2021-04-12   Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...      ...              ...                          ...
# 79988  2026-07-31   Amazon           iPhone              iPhone 16 128GB
# 79989  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79993  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79994  2026-07-31   Amazon           iPhone              iPhone 17 128GB
# 79997  2026-07-31   Amazon           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
df["Current_Price_USD"].value_counts()
# Out:
# Current_Price_USD
# 788.60     13
# 257.68     11
# 253.61     10
# 811.31     10
# 589.50      9
#            ..
# 787.89      1
# 896.49      1
# 1011.59     1
# 550.48      1
# 231.97      1
# Name: count, Length: 49611, dtype: int64

# %%
df['Current_Price_USD'].value_counts(dropna=False)
# Out:
# Current_Price_USD
# 788.60     13
# 257.68     11
# 253.61     10
# 811.31     10
# 589.50      9
#            ..
# 787.89      1
# 896.49      1
# 1011.59     1
# 550.48      1
# 231.97      1
# Name: count, Length: 49611, dtype: int64

# %%
df['Current_Price_USD'].unique()
# Out:
# array([435.81, 436.49, 422.73, ..., 861.39, 657.3 , 834.95])

# %%
df['Current_Price_USD'].nunique()
# Out:
# 49611

# %% [markdown]
# # data cleaning

# %%
#missing data
df.isna()
#true when a value is missing
# Out:
#         Date  Platform  Product_Category  Model_Name  Condition  \
# 0      False     False             False       False      False
# 1      False     False             False       False      False
# 2      False     False             False       False      False
# 3      False     False             False       False      False
# 4      False     False             False       False      False
# ...      ...       ...               ...         ...        ...
# 79995  False     False             False       False      False
# 79996  False     False             False       False      False
# 79997  False     False             False       False      False
# 79998  False     False             False       False      False
# 79999  False     False             False       False      False
#
#        Launch_Price_USD  Launch_Price_INR  Current_Price_USD  \
# 0                 False             False              False
# 1                 False             False              False
# ...

# %%
df.isna().sum()
#count per column,you use this one
# Out:
# Date                     0
# Platform                 0
# Product_Category         0
# Model_Name               0
# Condition                0
# Launch_Price_USD         0
# Launch_Price_INR         0
# Current_Price_USD        0
# Current_Price_INR        0
# Discount_Pct             0
# Sale_Event           73351
# Stock_Status             0
# Rating                   0
# Reviews_Count            0
# dtype: int64

# %%
df.isna().sum().sum()
#total across the whole table
# Out:
# np.int64(73351)

# %%
df.isna().mean()*100
# Out:
# Date                  0.00000
# Platform              0.00000
# Product_Category      0.00000
# Model_Name            0.00000
# Condition             0.00000
# Launch_Price_USD      0.00000
# Launch_Price_INR      0.00000
# Current_Price_USD     0.00000
# Current_Price_INR     0.00000
# Discount_Pct          0.00000
# Sale_Event           91.68875
# Stock_Status          0.00000
# Rating                0.00000
# Reviews_Count         0.00000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Platform, Product_Category, Model_Name, Condition, Launch_Price_USD, Launch_Price_INR, Current_Price_USD, Current_Price_INR, Discount_Pct, Sale_Event, Stock_Status, Rating, Reviews_Count]
# Index: []

# %%
df["Reviews_Count"]=df["Reviews_Count"].astype(float)
df
# Out:
#              Date  Platform Product_Category                   Model_Name  \
# 0      2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1      2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4      2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79995  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %%
df.memory_usage(deep=True)
# Out:
# Index                    132
# Date                 4720000
# Platform             4480086
# Product_Category     4297023
# Model_Name           5722511
# Condition            4480240
# Launch_Price_USD      640000
# Launch_Price_INR      640000
# Current_Price_USD     640000
# Current_Price_INR     640000
# Discount_Pct          640000
# Sale_Event           2769466
# Stock_Status         4625391
# Rating                640000
# Reviews_Count         640000
# dtype: int64

# %%
df.dtypes
#did the type change?
# Out:
# Date                  object
# Platform              object
# Product_Category      object
# Model_Name            object
# Condition             object
# Launch_Price_USD       int64
# Launch_Price_INR       int64
# Current_Price_USD    float64
# Current_Price_INR    float64
# Discount_Pct         float64
# Sale_Event            object
# Stock_Status          object
# Rating               float64
# Reviews_Count        float64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              Date  Platform Product_Category                   Model_Name  \
# 0      2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1      2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4      2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79995  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
# ...

# %%
df.isna().sum()
#repeated(first one is at the top)
# Out:
# Date                     0
# Platform                 0
# Product_Category         0
# Model_Name               0
# Condition                0
# Launch_Price_USD         0
# Launch_Price_INR         0
# Current_Price_USD        0
# Current_Price_INR        0
# Discount_Pct             0
# Sale_Event           73351
# Stock_Status             0
# Rating                   0
# Reviews_Count            0
# dtype: int64

# %% [markdown]
# # saving your clean data

# %%
#df.to_csv("transctions_clean.csv",index=False)
#check it worked by loading it back
#check=pd.read_csv("transactions_clean.csv")
#check.shape
